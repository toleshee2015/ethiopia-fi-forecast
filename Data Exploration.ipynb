# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"C:\Users\Administrator\data\eethiopia_fi_unified_data.csv")

# Display the first five rows
print(df.head())
# Out:
#   record_id parent_id  record_type  category         pillar  \
# 0  IMP_0001  EVT_0001  impact_link       NaN         ACCESS
# 1  IMP_0002  EVT_0001  impact_link       NaN          USAGE
# 2  IMP_0003  EVT_0001  impact_link       NaN          USAGE
# 3  IMP_0004  EVT_0002  impact_link       NaN         ACCESS
# 4  IMP_0005  EVT_0002  impact_link       NaN  AFFORDABILITY
#
#                                 indicator  indicator_code  \
# 0    Telebirr effect on Account Ownership             NaN
# 1       Telebirr effect on Telebirr Users             NaN
# 2     Telebirr effect on P2P Transactions             NaN
# 3         Safaricom effect on 4G Coverage             NaN
# 4  Safaricom effect on Data Affordability             NaN
#
#    indicator_direction  value_numeric  value_text  ... impact_direction  \
# 0                  NaN           15.0         NaN  ...         increase
# 1                  NaN            NaN         NaN  ...         increase
# ...

# %%
print("Shape:", df.shape)
# Out:
# Shape: (14, 35)

# %%
print(df.columns.tolist())
# Out:
# ['record_id', 'parent_id', 'record_type', 'category', 'pillar', 'indicator', 'indicator_code', 'indicator_direction', 'value_numeric', 'value_text', 'value_type', 'unit', 'observation_date', 'period_start', 'period_end', 'fiscal_year', 'gender', 'location', 'region', 'source_name', 'source_type', 'source_url', 'confidence', 'related_indicator', 'relationship_type', 'impact_direction', 'impact_magnitude', 'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country', 'collected_by', 'collection_date', 'original_text', 'notes']

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            14 non-null     str
#  1   parent_id            14 non-null     str
#  2   record_type          14 non-null     str
#  3   category             0 non-null      float64
#  4   pillar               14 non-null     str
#  5   indicator            14 non-null     str
#  6   indicator_code       0 non-null      float64
#  7   indicator_direction  0 non-null      float64
#  8   value_numeric        12 non-null     float64
#  9   value_text           0 non-null      float64
#  10  value_type           14 non-null     str
#  11  unit                 14 non-null     str
#  12  observation_date     14 non-null     str
#  13  period_start         0 non-null      float64
#  14  period_end           0 non-null      float64
#  15  fiscal_year          0 non-null      float64
# ...

# %%
print(df["record_id"].value_counts())
# Out:
# record_id
# IMP_0001    1
# IMP_0002    1
# IMP_0003    1
# IMP_0004    1
# IMP_0005    1
# IMP_0006    1
# IMP_0007    1
# IMP_0008    1
# IMP_0009    1
# IMP_0010    1
# IMP_0011    1
# IMP_0012    1
# IMP_0013    1
# IMP_0014    1
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['record_id', 'parent_id', 'record_type', 'category', 'pillar',
#        'indicator', 'indicator_code', 'indicator_direction', 'value_numeric',
#        'value_text', 'value_type', 'unit', 'observation_date', 'period_start',
#        'period_end', 'fiscal_year', 'gender', 'location', 'region',
#        'source_name', 'source_type', 'source_url', 'confidence',
#        'related_indicator', 'relationship_type', 'impact_direction',
#        'impact_magnitude', 'impact_estimate', 'lag_months', 'evidence_basis',
#        'comparable_country', 'collected_by', 'collection_date',
#        'original_text', 'notes'],
#       dtype='str')

# %%
print(df.isnull().sum())
# Out:
# record_id               0
# parent_id               0
# record_type             0
# category               14
# pillar                  0
# indicator               0
# indicator_code         14
# indicator_direction    14
# value_numeric           2
# value_text             14
# value_type              0
# unit                    0
# observation_date        0
# period_start           14
# period_end             14
# fiscal_year            14
# gender                  0
# location                0
# region                 14
# source_name            14
# source_type            14
# source_url             14
# confidence              0
# related_indicator       0
# relationship_type       0
# impact_direction        0
# impact_magnitude        0
# impact_estimate         2
# lag_months              0
# evidence_basis          0
# comparable_country      7
# collected_by            0
# collection_date         0
# original_text          14
# notes                   0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
import pandas as pd

excel_file = pd.ExcelFile(r"C:\Users\Administrator\data\ethiopia_fi_unified_data.xlsx")
print(excel_file.sheet_names)
# Out:
# ['ethiopia_fi_unified_data', 'Impact_sheet']

# %%
import pandas as pd

# Load Sheet 1
data = pd.read_excel(
    r"C:\Users\Administrator\data\ethiopia_fi_unified_data.xlsx",
    sheet_name="ethiopia_fi_unified_data"
)

# Load Sheet 2
impact_sheet = pd.read_excel(
    r"C:\Users\Administrator\data\ethiopia_fi_unified_data.xlsx",
    sheet_name="Impact_sheet"
)

# Preview Sheet 1
print(data.head())

# Preview Sheet 2
print(impact_sheet.head())
# Out:
#   record_id  record_type category  pillar               indicator  \
# 0  REC_0001  observation      NaN  ACCESS  Account Ownership Rate
# 1  REC_0002  observation      NaN  ACCESS  Account Ownership Rate
# 2  REC_0003  observation      NaN  ACCESS  Account Ownership Rate
# 3  REC_0004  observation      NaN  ACCESS  Account Ownership Rate
# 4  REC_0005  observation      NaN  ACCESS  Account Ownership Rate
#
#   indicator_code indicator_direction  value_numeric value_text  value_type  \
# 0  ACC_OWNERSHIP       higher_better           22.0        NaN  percentage
# 1  ACC_OWNERSHIP       higher_better           35.0        NaN  percentage
# 2  ACC_OWNERSHIP       higher_better           46.0        NaN  percentage
# 3  ACC_OWNERSHIP       higher_better           56.0        NaN  percentage
# 4  ACC_OWNERSHIP       higher_better           36.0        NaN  percentage
#
#    ... impact_direction impact_magnitude impact_estimate lag_months  \
# ...

# %%
import pandas as pd

reference_codes = pd.read_excel(r"C:\Users\Administrator\data\reference_codes.xlsx")

print(reference_codes.head())
print(reference_codes.columns)
print(reference_codes.info())
# Out:
#          field         code  \
# 0  record_type  observation
# 1  record_type        event
# 2  record_type  impact_link
# 3  record_type       target
# 4  record_type     baseline
#
#                                          description applies_to
# 0                Actual measured value from a source        All
# 1            Policy launch market event or milestone        All
# 2  Relationship between event and indicator (link...        All
# 3                     Policy target or official goal        All
# 4                      Starting point for comparison        All
# Index(['field', 'code', 'description', 'applies_to'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   field        71 non-null     str
#  1   code         71 non-null     str
#  2   description  71 non-null     str
#  3   applies_to   71 non-null     str
# ...

# %%
print(data["record_type"].value_counts())
# Out:
# record_type
# observation    30
# event          10
# target          3
# Name: count, dtype: int64

# %%
record_counts = data["record_type"].value_counts().reset_index()
record_counts.columns = ["Record Type", "Count"]
print(record_counts)
# Out:
#    Record Type  Count
# 0  observation     30
# 1        event     10
# 2       target      3

# %%
print(data["pillar"].value_counts())
# Out:
# pillar
# ACCESS           16
# USAGE            11
# GENDER            5
# AFFORDABILITY     1
# Name: count, dtype: int64

# %%
print(data["source_type"].value_counts())
# Out:
# source_type
# operator      15
# survey        10
# regulator      7
# research       4
# policy         3
# calculated     2
# news           2
# Name: count, dtype: int64

# %%
print(data["confidence"].value_counts())
# Out:
# confidence
# high      40
# medium     3
# Name: count, dtype: int64

# %%
print(data.columns.tolist())
# Out:
# ['record_id', 'record_type', 'category', 'pillar', 'indicator', 'indicator_code', 'indicator_direction', 'value_numeric', 'value_text', 'value_type', 'unit', 'observation_date', 'period_start', 'period_end', 'fiscal_year', 'gender', 'location', 'region', 'source_name', 'source_type', 'source_url', 'confidence', 'related_indicator', 'relationship_type', 'impact_direction', 'impact_magnitude', 'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country', 'collected_by', 'collection_date', 'original_text', 'notes']

# %%
import pandas as pd

data["observation_date"] = pd.to_datetime(
    data["observation_date"],
    errors="coerce"
)

# %%
print("Earliest observation:",
      data["observation_date"].min())

print("Latest observation:",
      data["observation_date"].max())
# Out:
# Earliest observation: 2014-12-31 00:00:00
# Latest observation: 2030-12-31 00:00:00

# %%
print(data["record_type"].value_counts())
# Out:
# record_type
# observation    30
# event          10
# target          3
# Name: count, dtype: int64

# %%
print(data["pillar"].value_counts())
# Out:
# pillar
# ACCESS           16
# USAGE            11
# GENDER            5
# AFFORDABILITY     1
# Name: count, dtype: int64

# %%
print(data["source_type"].value_counts())
# Out:
# source_type
# operator      15
# survey        10
# regulator      7
# research       4
# policy         3
# calculated     2
# news           2
# Name: count, dtype: int64

# %%
print(data["confidence"].value_counts())
# Out:
# confidence
# high      40
# medium     3
# Name: count, dtype: int64

# %%
print(data["indicator_code"].unique())
# Out:
# <StringArray>
# [     'ACC_OWNERSHIP',     'ACC_MM_ACCOUNT',         'ACC_4G_COV',
#      'ACC_MOBILE_PEN',          'ACC_FAYDA',      'USG_P2P_COUNT',
#       'USG_P2P_VALUE',      'USG_ATM_COUNT',      'USG_ATM_VALUE',
#       'USG_CROSSOVER', 'USG_TELEBIRR_USERS', 'USG_TELEBIRR_VALUE',
#     'USG_MPESA_USERS',   'USG_MPESA_ACTIVE',    'USG_ACTIVE_RATE',
#     'AFF_DATA_INCOME',        'GEN_GAP_ACC',       'GEN_MM_SHARE',
#      'GEN_GAP_MOBILE',       'EVT_TELEBIRR',      'EVT_SAFARICOM',
#           'EVT_MPESA',          'EVT_FAYDA',      'EVT_FX_REFORM',
#       'EVT_CROSSOVER',  'EVT_MPESA_INTEROP',       'EVT_ETHIOPAY',
#           'EVT_NFIS2',   'EVT_SAFCOM_PRICE']
# Length: 29, dtype: str

# %%
print("Total indicators:",
      data["indicator_code"].nunique())
# Out:
# Total indicators: 29

# %%
coverage = (
    data.groupby("indicator_code")
        .agg(
            observations=("record_id", "count"),
            first_date=("observation_date", "min"),
            last_date=("observation_date", "max")
        )
)

print(coverage)
# Out:
#                     observations first_date  last_date
# indicator_code
# ACC_4G_COV                     2 2023-06-30 2025-06-30
# ACC_FAYDA                      4 2024-08-15 2028-12-31
# ACC_MM_ACCOUNT                 2 2021-12-31 2024-11-29
# ACC_MOBILE_PEN                 1 2025-12-31 2025-12-31
# ACC_OWNERSHIP                  7 2014-12-31 2025-12-31
# AFF_DATA_INCOME                1 2024-12-31 2024-12-31
# EVT_CROSSOVER                  1 2024-10-01 2024-10-01
# EVT_ETHIOPAY                   1 2025-12-18 2025-12-18
# EVT_FAYDA                      1 2024-01-01 2024-01-01
# EVT_FX_REFORM                  1 2024-07-29 2024-07-29
# EVT_MPESA                      1 2023-08-01 2023-08-01
# EVT_MPESA_INTEROP              1 2025-10-27 2025-10-27
# EVT_NFIS2                      1 2021-09-01 2021-09-01
# EVT_SAFARICOM                  1 2022-08-01 2022-08-01
# EVT_SAFCOM_PRICE               1 2025-12-15 2025-12-15
# EVT_TELEBIRR                   1 2021-05-17 2021-05-17
# ...

# %%
events = data[data["record_type"] == "event"]

print(events[[
    "record_id",
    "indicator",
    "observation_date",
    "pillar"
]])
# Out:
#    record_id                               indicator observation_date pillar
# 33  EVT_0001                         Telebirr Launch       2021-05-17    NaN
# 34  EVT_0002    Safaricom Ethiopia Commercial Launch       2022-08-01    NaN
# 35  EVT_0003                  M-Pesa Ethiopia Launch       2023-08-01    NaN
# 36  EVT_0004        Fayda Digital ID Program Rollout       2024-01-01    NaN
# 37  EVT_0005         Foreign Exchange Liberalization       2024-07-29    NaN
# 38  EVT_0006     P2P Transaction Count Surpasses ATM       2024-10-01    NaN
# 39  EVT_0007            M-Pesa EthSwitch Integration       2025-10-27    NaN
# 40  EVT_0008  EthioPay Instant Payment System Launch       2025-12-18    NaN
# 41  EVT_0009                 NFIS-II Strategy Launch       2021-09-01    NaN
# 42  EVT_0010       Safaricom Ethiopia Price Increase       2025-12-15    NaN

# %%
print(impact_sheet.columns.tolist())
# Out:
# ['record_id', 'parent_id', 'record_type', 'category', 'pillar', 'indicator', 'indicator_code', 'indicator_direction', 'value_numeric', 'value_text', 'value_type', 'unit', 'observation_date', 'period_start', 'period_end', 'fiscal_year', 'gender', 'location', 'region', 'source_name', 'source_type', 'source_url', 'confidence', 'related_indicator', 'relationship_type', 'impact_direction', 'impact_magnitude', 'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country', 'collected_by', 'collection_date', 'original_text', 'notes']

# %%
print(impact_sheet.head())
# Out:
#   record_id parent_id  record_type  category         pillar  \
# 0  IMP_0001  EVT_0001  impact_link       NaN         ACCESS
# 1  IMP_0002  EVT_0001  impact_link       NaN          USAGE
# 2  IMP_0003  EVT_0001  impact_link       NaN          USAGE
# 3  IMP_0004  EVT_0002  impact_link       NaN         ACCESS
# 4  IMP_0005  EVT_0002  impact_link       NaN  AFFORDABILITY
#
#                                 indicator  indicator_code  \
# 0    Telebirr effect on Account Ownership             NaN
# 1       Telebirr effect on Telebirr Users             NaN
# 2     Telebirr effect on P2P Transactions             NaN
# 3         Safaricom effect on 4G Coverage             NaN
# 4  Safaricom effect on Data Affordability             NaN
#
#    indicator_direction  value_numeric  value_text  ... impact_direction  \
# 0                  NaN           15.0         NaN  ...         increase
# 1                  NaN            NaN         NaN  ...         increase
# ...

# %%
print(impact_sheet.columns.tolist())
print(impact_sheet.head())
# Out:
# ['record_id', 'parent_id', 'record_type', 'category', 'pillar', 'indicator', 'indicator_code', 'indicator_direction', 'value_numeric', 'value_text', 'value_type', 'unit', 'observation_date', 'period_start', 'period_end', 'fiscal_year', 'gender', 'location', 'region', 'source_name', 'source_type', 'source_url', 'confidence', 'related_indicator', 'relationship_type', 'impact_direction', 'impact_magnitude', 'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country', 'collected_by', 'collection_date', 'original_text', 'notes']
#   record_id parent_id  record_type  category         pillar  \
# 0  IMP_0001  EVT_0001  impact_link       NaN         ACCESS
# 1  IMP_0002  EVT_0001  impact_link       NaN          USAGE
# 2  IMP_0003  EVT_0001  impact_link       NaN          USAGE
# 3  IMP_0004  EVT_0002  impact_link       NaN         ACCESS
# 4  IMP_0005  EVT_0002  impact_link       NaN  AFFORDABILITY
#
#                                 indicator  indicator_code  \
# ...
